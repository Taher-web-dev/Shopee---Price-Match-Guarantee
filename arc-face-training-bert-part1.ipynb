# %%
# !wget --quiet https://raw.githubusercontent.com/tensorflow/models/master/official/nlp/bert/tokenization.py
import pandas as pd
import numpy as np 
import tensorflow as tf 
import tensorflow_hub as hub 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tokenization 
import warnings
warnings.filterwarnings("ignore")
import math
import re
import collections
import langid
import fasttext
import string 
from transformers import BertTokenizer,TFBertModel

# %%
tokenizer = BertTokenizer.from_pretrained("cahya/bert-base-indonesian-522M")
model = TFBertModel.from_pretrained("cahya/bert-base-indonesian-522M")
# Out:
# Downloading:   0%|          | 0.00/230k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/468 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/545M [00:00<?, ?B/s]
# Some layers from the model checkpoint at cahya/bert-base-indonesian-522M were not used when initializing TFBertModel: ['mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at cahya/bert-base-indonesian-522M.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
test = pd.read_csv("../input/shopee-product-matching/train.csv")

# %%
# Take a look at the datas
test.head()
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
#
#                                                title  label_group
# 0                          Paper Bag Victoria Secret    249114794
# 1  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...   2937985045
# 2        Maling TTS Canned Pork Luncheon Meat 397 gr   2395904891
# 3  Daster Batik Lengan pendek - Motif Acak / Camp...   4093212188
# 4                  Nescafe \xc3\x89clair Latte 220ml   3648931069

# %%
# take a look at the title feature
test.title
# Out:
# 0                                Paper Bag Victoria Secret
# 1        Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...
# 2              Maling TTS Canned Pork Luncheon Meat 397 gr
# 3        Daster Batik Lengan pendek - Motif Acak / Camp...
# 4                        Nescafe \xc3\x89clair Latte 220ml
#                                ...
# 34245    Masker Bahan Kain Spunbond Non Woven 75 gsm 3 ...
# 34246      MamyPoko Pants Royal Soft - S 70 - Popok Celana
# 34247    KHANZAACC Robot RE101S 1.2mm Subwoofer Bass Me...
# 34248    Kaldu NON MSG HALAL Mama Kamu Ayam Kampung , S...
# 34249    FLEX TAPE PELAPIS BOCOR / ISOLASI AJAIB / ANTI...
# Name: title, Length: 34250, dtype: object

# %% [markdown]
# ===> two obvious thing can be underlined throw this first looking at title feature :
#   - There is series of caratcters which don't bring any meaning ; we should explorate their occurences on the data which represent title.
#   - Title are represented randomly with upper and lower case form .So we should lower cased all words and caracters which are presents in our title datas.

# %%
# Examinate the frequency of the unusual caracters , observed above in data title.
df=test.title.str.findall(r"(\\\w)")
df = pd.DataFrame({"regular_expression":df.values})
df["regular_expression"] = df["regular_expression"].astype("str")
df = df.loc[df["regular_expression"] !="[]",:]
print(f"Theses random caracters appear {len(df)} timses in our titles")
# Out:
# Theses random caracters appear 705 timses in our titles

# %% [markdown]
# ===> We need to handle theses random caracters in our processing steps of datas.

# %% [markdown]
# ===> We should also mention that there is some caracters and symbols that we should get rid of them because they don't bring any value for our downstream task. theses caracters like : "/" ,"-","/"...

# %%
# Extract the top 100 most common words in our titles.
corpus = []
for tx in test["title"].values:
    corpus.extend(tx.lower().split())

counter = collections.Counter(corpus)
list(zip(*(counter.most_common(100))))
# Out:
# [('/',
#   '-',
#   'anak',
#   'wanita',
#   'original',
#   '1',
#   'murah',
#   'tas',
#   'dan',
#   'pria',
#   'masker',
#   'untuk',
#   '|',
#   'bayi',
#   '&',
#   'ml',
#   'anti',
#   'set',
#   '2',
#   'baby',
#   '3',
#   'tangan',
#   'air',
#   'isi',
#   'kaos',
#   'motif',
#   'sepatu',
#   'warna',
#   'baju',
#   'cream',
#   'mini',
#   'premium',
#   'import',
#   'celana',
#   'alat',
#   'bahan',
#   'gr',
#   'polos',
#   'rambut',
#   'led',
#   '+',
#   'fashion',
#   'serum',
#   'mask',
#   'jam',
#   'pcs',
#   'x',
#   'in',
#   'lampu',
#   'mainan',
#   'termurah',
#   'by',
#   'case',
#   '(',
#   'bag',
#   '6',
#   'korea',
#   'hijab',
#   'rak',
#   'panjang',
#   '4',
#   '5',
#   'kain',
#   'usb',
#   'sarung',
#   'karakter',
#   ')',
#   'dress',
#   'sandal',
#   'sabun',
#   'pro',
#   'hp',
#   'hitam',
#   'plastik',
#   'cod',
#   '100',
#   'paket',
#   'plus',
#   'free',
#   'bisa',
#   'white',
#   'jumbo',
#   'dengan',
#   'botol',
#   '10',
#   'new',
#   'putih',
#   'tempat',
#   'box',
#   'gamis',
#   'holder',
#   'size',
#   'mobil',
#   'kaki',
#   'gel',
#   'super',
#   'wajah',
#   'bpom',
#   'dompet',
#   'jilbab'),
#  (8616,
#   5221,
#   1916,
#   1820,
#   1681,
#   1400,
#   1363,
#   1192,
#   1157,
#   1122,
#   1111,
#   1068,
#   1066,
#   1061,
#   1042,
#   1028,
#   1018,
#   992,
#   931,
#   887,
#   868,
#   862,
#   836,
#   814,
#   811,
#   807,
#   796,
#   792,
#   791,
#   787,
#   786,
#   780,
#   746,
#   743,
#   712,
#   699,
#   674,
#   669,
#   658,
#   598,
#   589,
#   584,
#   568,
#   566,
#   552,
#   550,
#   548,
#   531,
#   522,
#   520,
#   517,
#   514,
#   513,
#   495,
#   485,
#   481,
#   480,
#   476,
#   470,
#   469,
#   464,
#   462,
#   461,
#   460,
#   458,
#   449,
#   441,
#   440,
#   436,
#   428,
#   428,
#   427,
#   424,
#   420,
#   419,
#   419,
#   417,
#   409,
#   407,
#   403,
#   402,
#   399,
#   395,
#   394,
#   394,
#   394,
#   393,
#   393,
#   391,
#   391,
#   386,
#   384,
#   384,
#   383,
#   383,
#   380,
#   377,
#   376,
#   372,
#   371)]

# %%
# Extract the least common words in our titles.
list(zip(*(counter.most_common())))[-101:-1]
# Out:
# [('/',
#   '-',
#   'anak',
#   'wanita',
#   'original',
#   '1',
#   'murah',
#   'tas',
#   'dan',
#   'pria',
#   'masker',
#   'untuk',
#   '|',
#   'bayi',
#   '&',
#   'ml',
#   'anti',
#   'set',
#   '2',
#   'baby',
#   '3',
#   'tangan',
#   'air',
#   'isi',
#   'kaos',
#   'motif',
#   'sepatu',
#   'warna',
#   'baju',
#   'cream',
#   'mini',
#   'premium',
#   'import',
#   'celana',
#   'alat',
#   'bahan',
#   'gr',
#   'polos',
#   'rambut',
#   'led',
#   '+',
#   'fashion',
#   'serum',
#   'mask',
#   'jam',
#   'pcs',
#   'x',
#   'in',
#   'lampu',
#   'mainan',
#   'termurah',
#   'by',
#   'case',
#   '(',
#   'bag',
#   '6',
#   'korea',
#   'hijab',
#   'rak',
#   'panjang',
#   '4',
#   '5',
#   'kain',
#   'usb',
#   'sarung',
#   'karakter',
#   ')',
#   'dress',
#   'sandal',
#   'sabun',
#   'pro',
#   'hp',
#   'hitam',
#   'plastik',
#   'cod',
#   '100',
#   'paket',
#   'plus',
#   'free',
#   'bisa',
#   'white',
#   'jumbo',
#   'dengan',
#   'botol',
#   '10',
#   'new',
#   'putih',
#   'tempat',
#   'box',
#   'gamis',
#   'holder',
#   'size',
#   'mobil',
#   'kaki',
#   'gel',
#   'super',
#   'wajah',
#   'bpom',
#   'dompet',
#   'jilbab',
#   'body',
#   'black',
#   'tali',
#   'pendek',
#   '8',
#   'samsung',
#   '100%',
#   'bluetooth',
#   'serbaguna',
#   'portable',
#   '100ml',
#   'promo',
#   'cover',
#   'karet',
#   'hand',
#   'iphone',
#   'kabel',
#   'hair',
#   'grosir',
#   'motor',
#   'buku',
#   'face',
#   'lip',
#   'gram',
#   'model',
#   'kotak',
#   '12',
#   'soft',
#   'muslim',
#   'pembersih',
#   'lipat',
#   'for',
#   'minyak',
#   'digital',
#   'cm',
#   'ori',
#   'tahun',
#   'spray',
#   'selempang',
#   '30',
#   'kg',
#   'bunga',
#   'oppo',
#   '7',
#   'headset',
#   'kulit',
#   'mukena',
#   'di',
#   'katun',
#   'silikon',
#   'color',
#   'full',
#   'charger',
#   'matte',
#   'xiaomi',
#   'whitening',
#   'topi',
#   'skin',
#   '[',
#   'asli',
#   'instan',
#   'dewasa',
#   'madu',
#   'up',
#   'facial',
#   'mandi',
#   'obat',
#   ']',
#   'dinding',
#   'c',
#   '1kg',
#   'glow',
#   'kaca',
#   'stainless',
#   'susu',
#   'terbaru',
#   'water',
#   'jeans',
#   'dapur',
#   'lotion',
#   'kacamata',
#   'ukuran',
#   '50',
#   'sport',
#   'lengan',
#   'gold',
#   'ready',
#   'wardah',
#   'pink',
#   'toner',
#   'with',
#   'koko',
#   'gantungan',
#   'powder',
#   'oil',
#   'mata',
#   'terlaris',
#   'joyko',
#   'cuci',
#   'l',
#   'the',
#   'kuas',
#   'lucu',
#   'all',
#   'perempuan',
#   'beauty',
#   'make',
#   'earphone',
#   'garansi',
#   'soap',
#   'sepeda',
#   'ikat',
#   'setelan',
#   'dalam',
#   'acne',
#   'besar',
#   'rajut',
#   'speaker',
#   'series',
#   '2020',
#   'resmi',
#   'pants',
#   'tebal',
#   'pouch',
#   'brush',
#   'wash',
#   'jelly',
#   'waterproof',
#   'tanpa',
#   'kecil',
#   'wireless',
#   'khimar',
#   'asi',
#   'sweater',
#   'extra',
#   'bubble',
#   'care',
#   'cat',
#   'merah',
#   'coklat',
#   'on',
#   'buah',
#   'refill',
#   'silicone',
#   'kayu',
#   'micro',
#   'softlens',
#   'ransel',
#   'max',
#   'light',
#   'kids',
#   '3d',
#   'double',
#   'milk',
#   'm',
#   'robot',
#   'kucing',
#   'and',
#   'tunik',
#   'kosmetik',
#   'pakaian',
#   'redmi',
#   'pisau',
#   '20',
#   'xl',
#   'to',
#   'collagen',
#   'best',
#   'glass',
#   'travel',
#   'g',
#   'stand',
#   'pelindung',
#   'vivo',
#   'multifungsi',
#   'gigi',
#   'natural',
#   'elektrik',
#   'universal',
#   'quality',
#   'handuk',
#   'baterai',
#   'magic',
#   'bra',
#   'type',
#   'parfum',
#   'ring',
#   'bumbu',
#   'herbal',
#   'kertas',
#   'pensil',
#   '15',
#   'bulu',
#   'food',
#   'vitamin',
#   '200',
#   'liquid',
#   'pen',
#   'non',
#   'kemasan',
#   'jepit',
#   'cair',
#   'fresh',
#   'makanan',
#   'kipas',
#   'tissue',
#   'pack',
#   'bantal',
#   '500',
#   'note',
#   ',',
#   'daster',
#   'tidur',
#   'phone',
#   'lem',
#   'tempered',
#   'mi',
#   'kit',
#   'bali',
#   'casual',
#   'bola',
#   'olahraga',
#   'timbangan',
#   'gantung',
#   'meja',
#   'tahan',
#   'tablet',
#   'ikan',
#   '60',
#   'sikat',
#   'pompa',
#   'edukasi',
#   '11',
#   'sachet',
#   'casing',
#   'harga',
#   'makan',
#   'high',
#   'bandana',
#   'balon',
#   'tape',
#   'susun',
#   'blender',
#   'filter',
#   'biru',
#   'stiker',
#   'rasa',
#   'kemeja',
#   'dekorasi',
#   'kartu',
#   'sneakers',
#   'organik',
#   'telur',
#   'mie',
#   'my',
#   'mesin',
#   'realme',
#   'busa',
#   'kurma',
#   'lap',
#   'stick',
#   'data',
#   'al',
#   'pigeon',
#   'emina',
#   'badan',
#   'piring',
#   'puzzle',
#   'sendok',
#   'brightening',
#   'angin',
#   'pemutih',
#   'hanasui',
#   'panci',
#   'steel',
#   'cowok',
#   'fit',
#   'jaket',
#   '9',
#   '30ml',
#   'syari',
#   '24',
#   'card',
#   'slip',
#   'boneka',
#   'bulat',
#   'viva',
#   'bentuk',
#   'tea',
#   'rumah',
#   'makeup',
#   'cewek',
#   'kartun',
#   'storage',
#   'cotton',
#   'diamond',
#   'fast',
#   'meter',
#   'dot',
#   'aksesoris',
#   'piyama',
#   'sanitizer',
#   'packing',
#   'baru',
#   'bass',
#   'shower',
#   'a5',
#   'couple',
#   'pulpen',
#   'batik',
#   'touch',
#   'serut',
#   'kantong',
#   'pure',
#   'daily',
#   'minum',
#   'seller',
#   'bening',
#   'essence',
#   'organizer',
#   'mic',
#   'bordir',
#   'cukur',
#   'slim',
#   'mix',
#   'distro',
#   'real',
#   'scuba',
#   'blue',
#   'sheet',
#   'kapsul',
#   'wrap',
#   'laki',
#   'cleanser',
#   'handsfree',
#   'pinggang',
#   'lembut',
#   'bb',
#   'panas',
#   'cup',
#   'foam',
#   'goreng',
#   'kualitas',
#   'handphone',
#   '//',
#   'kue',
#   'elastis',
#   'nivea',
#   'per',
#   '500ml',
#   'bedak',
#   '50ml',
#   'inch',
#   'pot',
#   'daun',
#   '200ml',
#   'basah',
#   'maxy',
#   's',
#   'maxi',
#   'kerudung',
#   'simple',
#   'sticker',
#   'besi',
#   'kopi',
#   'shampoo',
#   'transparan',
#   'tripod',
#   'listrik',
#   'sale',
#   'night',
#   '40',
#   'uv',
#   'tisu',
#   'lightening',
#   'booster',
#   'bubuk',
#   'atasan',
#   'hoodie',
#   'smart',
#   'hot',
#   'mixer',
#   'star',
#   'strip',
#   'selfie',
#   'tv',
#   'aloe',
#   'kran',
#   'teh',
#   'batam',
#   'tanaman',
#   'sd',
#   'big',
#   'you',
#   'halus',
#   'tutup',
#   'somebymi',
#   'android',
#   'hias',
#   'off',
#   'berkualitas',
#   'kuning',
#   'halal',
#   'instant',
#   '250',
#   'clip',
#   'cap',
#   'gas',
#   'xs',
#   'bergo',
#   'scarlett',
#   'bottle',
#   'stereo',
#   'kitchen',
#   'merk',
#   'pump',
#   'organic',
#   'cake',
#   'vanila',
#   '60ml',
#   'screen',
#   'men',
#   'gratis',
#   'liter',
#   'safety',
#   '150ml',
#   'charging',
#   'korean',
#   'cantik',
#   'kepala',
#   'classic',
#   'kamar',
#   'galaxy',
#   'watch',
#   'ayam',
#   'lapis',
#   'one',
#   'usia',
#   'bts',
#   'sponge',
#   'niacin',
#   'power',
#   'silver',
#   'gula',
#   'green',
#   'peel',
#   'tint',
#   '!!',
#   'perfect',
#   '500gr',
#   'popok',
#   'xxl',
#   'garnier',
#   'cable',
#   'jersey',
#   'gambar',
#   'a7',
#   'implora',
#   'bawang',
#   'cussons',
#   'paper',
#   '400',
#   'bando',
#   'smartphone',
#   'apple',
#   'dispenser',
#   'audio',
#   'cleansing',
#   'roll',
#   '[bpom]',
#   'long',
#   'impor',
#   'alas',
#   'gaya',
#   '2in1',
#   'camera',
#   'mm',
#   '\\xe2\\x9d\\xa4',
#   'stock',
#   'hdmi',
#   'kamera',
#   'rayon',
#   'keranjang',
#   'moisturizing',
#   'jerawat',
#   'sprei',
#   'dark',
#   'a3s',
#   'lipstick',
#   'unisex',
#   'rubber',
#   'kpop',
#   'warni',
#   'cairan',
#   'king',
#   'pad',
#   'sorex',
#   'aqua',
#   'training',
#   'retro',
#   'ban',
#   'kunci',
#   'bintang',
#   'pet',
#   'lemon',
#   'masak',
#   'vera',
#   'strap',
#   'spons',
#   'car',
#   'tulis',
#   'outdoor',
#   'adapter',
#   'dual',
#   '(cod)',
#   'helm',
#   'eye',
#   'philips',
#   'pelangsing',
#   'cute',
#   'spf',
#   'single',
#   'multi',
#   '150',
#   'alis',
#   '250ml',
#   'n',
#   'pena',
#   'clear',
#   'grade',
#   'sambungan',
#   'velvet',
#   'sugar',
#   'mawar',
#   'basic',
#   'band',
#   'backpack',
#   'mika',
#   'microphone',
#   'sling',
#   '25',
#   'a',
#   'layar',
#   'love',
#   'kering',
#   'lengkap',
#   'onemed',
#   'hijau',
#   'gaming',
#   'bayar',
#   'nail',
#   'huruf',
#   'hanger',
#   'beras',
#   'kekinian',
#   'krim',
#   'kuku',
#   'eyebrow',
#   'perekat',
#   'f9',
#   'some',
#   'nano',
#   'sekolah',
#   'renda',
#   'teether',
#   '3in1',
#   'control',
#   'yuja',
#   'a5s',
#   'cetakan',
#   'pita',
#   'belt',
#   'little',
#   '[bayar',
#   'varian',
#   'gie',
#   'tempel',
#   'navy',
#   'laundry',
#   '6s',
#   'ultra',
#   'moscrepe',
#   'tambahan',
#   'lcd',
#   'unik',
#   'overall',
#   'foundation',
#   'watt',
#   'jepang',
#   'sendal',
#   'mangkok',
#   'cd',
#   'penyimpanan',
#   'me',
#   'penutup',
#   'starter',
#   'shield',
#   '(bisa',
#   'pashmina',
#   'madame',
#   'flash',
#   'flexible',
#   'tinggi',
#   'a9',
#   'battery',
#   'skincare',
#   'wipes',
#   'kancing',
#   'keren',
#   'payung',
#   'ply',
#   'hn',
#   'paris',
#   'flip',
#   'part',
#   'pan',
#   'lemari',
#   'liptint',
#   'dari',
#   'perlengkapan',
#   'wallpaper',
#   'lakban',
#   'f1s',
#   'protection',
#   'keset',
#   'kulkas',
#   'day',
#   'miracle',
#   'moisture',
#   'flower',
#   'toilet',
#   'electric',
#   'roda',
#   'kerja',
#   'rok',
#   'snack',
#   'tenda',
#   'style',
#   'oleh',
#   'analog',
#   'kombinasi',
#   'animal',
#   'pop',
#   'u',
#   'gluta',
#   'ms',
#   'selang',
#   'bulan',
#   'life',
#   'of',
#   'glossy',
#   'mutiara',
#   'pijat',
#   'keju',
#   'hujan',
#   'laptop',
#   'belajar',
#   'segi',
#   'square',
#   'gurita',
#   'art',
#   'roti',
#   'magnet',
#   'i',
#   'mist',
#   '3.0',
#   'pcs)',
#   'ada',
#   'coffee',
#   'komedo',
#   'powerbank',
#   'bagus',
#   'f11',
#   'jarum',
#   'red',
#   'grip',
#   'a37',
#   'xr',
#   'hiasan',
#   'ecer',
#   'niqab',
#   'snail',
#   'kawat',
#   'saus',
#   'catok',
#   'muat',
#   'cheek',
#   'brown',
#   'hamil',
#   'telon',
#   'telinga',
#   '!!!',
#   'bh',
#   'crack',
#   'rice',
#   'balm',
#   'top',
#   'royal',
#   'pc',
#   'game',
#   '||',
#   'beli',
#   'ac',
#   'cadar',
#   'pixy',
#   'baso',
#   'chino',
#   'ice',
#   'adem',
#   'hello',
#   'women',
#   '[cod]',
#   'mouse',
#   '180',
#   'days',
#   'busui',
#   'pocket',
#   'laki-laki',
#   'korset',
#   'tube',
#   'kanebo',
#   'waistbag',
#   'depan',
#   '15gr',
#   'dua',
#   'unicorn',
#   'quran',
#   'spatula',
#   '100gr',
#   'foil',
#   '250gr',
#   'shoes',
#   'cermin',
#   'otg',
#   'uk',
#   'plisket',
#   'protector',
#   'thailand',
#   'adidas',
#   'a71',
#   'a31',
#   '120',
#   'frozen',
#   'nature',
#   'softcase',
#   'pasta',
#   'keran',
#   'palsu',
#   'belakang',
#   'low',
#   'gelas',
#   'f5',
#   'pakai',
#   'scrub',
#   'pintu',
#   'nipple',
#   'pelancar',
#   'bendera',
#   'debu',
#   'tote',
#   'sedotan',
#   'back',
#   'chocolate',
#   'diy',
#   'vintage',
#   'pencil',
#   'cargo',
#   'nyamuk',
#   'fan',
#   'praktis',
#   'sajadah',
#   'kantor',
#   'hook',
#   'standing',
#   'ulang',
#   'cleaner',
#   'kitty',
#   'bear',
#   'receiver',
#   'over',
#   '3.5mm',
#   'normal',
#   'selimut',
#   'leher',
#   'indonesia',
#   'penghilang',
#   'home',
#   'arab',
#   'gym',
#   'sayur',
#   'manual',
#   'cod)',
#   'tpu',
#   'happy',
#   'running',
#   'vanilla',
#   'futsal',
#   'salep',
#   'jakarta',
#   'legging',
#   'bio',
#   'herborist',
#   'kolam',
#   'deep',
#   'girl',
#   'junior',
#   'rose',
#   '10ml',
#   '(1',
#   'ruangan',
#   'sudut',
#   'smile',
#   'cushion',
#   'print',
#   'rainbow',
#   'glowing',
#   'charge',
#   'deodorant',
#   'edition',
#   'penjepit',
#   'sim',
#   'jaring',
#   'corona',
#   'miyako',
#   'flat',
#   'salur',
#   'sambal',
#   'touchscreen',
#   'jamur',
#   'candy',
#   'no',
#   'quartz',
#   '360',
#   '1000',
#   'creamy',
#   'reno',
#   'wall',
#   'perawatan',
#   'colour',
#   'angka',
#   'gigitan',
#   'atau',
#   'rantai',
#   'dry',
#   'a1k',
#   'prime',
#   'jeruk',
#   'tepung',
#   'bonus',
#   'gelang',
#   'bioaqua',
#   'kelambu',
#   'f7',
#   'sweety',
#   'go',
#   'lubang',
#   '16',
#   'ink',
#   'garpu',
#   '45',
#   '18',
#   'cokelat',
#   'line',
#   'aci',
#   'kapas',
#   'pasir',
#   'shampo',
#   'a12',
#   'beautetox',
#   'solution',
#   'kode',
#   'wolfis',
#   'mpasi',
#   'bright',
#   'earloop',
#   'spon',
#   'emas',
#   '(isi',
#   'batre',
#   'quick',
#   '90',
#   'sauce',
#   'a4',
#   'microfiber',
#   '[bisa',
#   '120ml',
#   'eyeshadow',
#   'repair',
#   '!',
#   'saringan',
#   'man',
#   'bt21',
#   'tabung',
#   'reguler',
#   'minuman',
#   'bandung',
#   'grey',
#   'perlak',
#   'good',
#   'ala',
#   ...)]

# %%
# let's the detect the language of theses titles.
languages = []
for tit in test.title.values :
    languages.append(langid.classify(tit)[0])

# %%
languages = collections.Counter(languages)

# %%
# Display the table of languages used in the title description
languages = pd.DataFrame(languages,index=["frequency"])
languages
# Out:
#               en   mt    id   fr  xh   tl   fi    es    it  af  ...  sq  nb  \
# frequency  13286  766  6762  912  77  590  533  1032  1182  74  ...   9  34
#
#            qu  sk  gl  nn  fo  an  ga  wa
# frequency  10  22  17  35   5  14  10   2
#
# [1 rows x 58 columns]

# %% [markdown]
# ===> As we can see on  the table above, there is many languages used in our title descriptions.

# %%
def clean_title(tx):
    tx = tx.lower()
    tx = re.sub(r"\\(\w)+(\d)+"," ",tx)
    #tx = re.sub(r"[\\/-+_*[]()]"," ",tx)
    tx = re.sub(r"(\d+),(\d+)",r"\1.\2",tx)
    for p in string.punctuation :
        if p !="." :
          tx=tx.replace(p," ")
    tx = re.sub(r"\s+"," ",tx)
    
    return tx

# %%
test["cleaned_title"] = test["title"].map(clean_title)

# %%
lb= LabelEncoder()
test["encoded_label_group"] = lb.fit_transform(test["label_group"].values)

# %%
#sent= tokenizer.encode_plus(test.loc[0,"cleaned_title"],add_special_tokens=True,padding="max_length",max_length=\
                                  #70)

# %%
def bert_encode(seq_data,tokenizer,max_len=512):
    all_tokens = []
    all_masks = []
    
    for seq in seq_data :
        sent= tokenizer.encode_plus(seq,add_special_tokens=True,padding="max_length",max_length=\
                                  max_len,truncation=True)
        #tx = tx[:max_len-2]
        #tx = ['[CLS]'] + tx + ['[SEP]']
        #tokens = tokenizer.convert_tokens_to_ids(tx)
        #seq_len = len(tokens)
        #pad_len = max_len - seq_len 
        #tokens = tokens + [0] * pad_len
        #masks = [1] * seq_len + [0] * pad_len
        #segments = [0] * max_len
        
        all_tokens.append(sent.get("input_ids"))
        all_masks.append(sent.get("attention_mask"))
        #all_segments.append(segments)
    all_tokens = np.vstack(all_tokens)
    all_masks = np.vstack(all_masks)
    return all_tokens,all_masks
    #,np.array(all_segments)

# %%
class ArcMarginProduct(tf.keras.layers.Layer):
    '''
    Implements large margin arc distance.

    Reference:
        https://arxiv.org/pdf/1801.07698.pdf
        https://github.com/lyakaap/Landmark2019-1st-and-3rd-Place-Solution/
            blob/master/src/modeling/metric_learning.py
    '''
    def __init__(self, n_classes, s=30, m=0.50, easy_margin=False,
                 ls_eps=0.0, **kwargs):

        super(ArcMarginProduct, self).__init__(**kwargs)

        self.n_classes = n_classes
        self.s = s
        self.m = m
        self.ls_eps = ls_eps
        self.easy_margin = easy_margin
        self.cos_m = tf.math.cos(m)
        self.sin_m = tf.math.sin(m)
        self.th = tf.math.cos(math.pi - m)
        self.mm = tf.math.sin(math.pi - m) * m

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'n_classes': self.n_classes,
            's': self.s,
            'm': self.m,
            'ls_eps': self.ls_eps,
            'easy_margin': self.easy_margin,
        })
        return config

    def build(self, input_shape):
        super(ArcMarginProduct, self).build(input_shape[0])

        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[0][-1]), self.n_classes),
            initializer='glorot_uniform',
            dtype='float32',
            trainable=True,
            regularizer=None)

    def call(self, inputs):
        X, y = inputs
        y = tf.cast(y, dtype=tf.int32)
        cosine = tf.matmul(
            tf.math.l2_normalize(X, axis=1),
            tf.math.l2_normalize(self.W, axis=0)
        )
        sine = tf.math.sqrt(1.0 - tf.math.pow(cosine, 2))
        phi = cosine * self.cos_m - sine * self.sin_m
        if self.easy_margin:
            phi = tf.where(cosine > 0, phi, cosine)
        else:
            phi = tf.where(cosine > self.th, phi, cosine - self.mm)
        one_hot = tf.cast(
            tf.one_hot(y, depth=self.n_classes),
            dtype=cosine.dtype
        )
        if self.ls_eps > 0:
            one_hot = (1 - self.ls_eps) * one_hot + self.ls_eps / self.n_classes

        output = (one_hot * phi) + ((1.0 - one_hot) * cosine)
        output *= self.s
        return output

# %%
def build_model(bert_layer,N_CLASSES,max_len=512):
    margin = ArcMarginProduct(
            n_classes = N_CLASSES, 
            s = 30, 
            m = 0.5, 
            name='head/arc_margin', 
            dtype='float32')
    tokens = tf.keras.layers.Input(shape=(max_len,),dtype=tf.int32)
    #masks = tf.keras.layers.Input(shape=(max_len,),dtype=tf.int32)
    #segments = tf.keras.layers.Input(shape=(max_len,),dtype=tf.int32)
    y = tf.keras.layers.Input(shape=(),dtype=tf.int32)
    bert = bert_layer.bert([tokens])
    cls = bert.pooler_output 
    x = tf.keras.layers.BatchNormalization()(cls)
    #x = tf.keras.layers.Dropout(0.4)(x)
    #x = tf.keras.layers.Dense(emb_size)(x)
    #emb = tf.keras.layers.BatchNormalization()(x)
    mar = margin([x,y])
    output = tf.keras.layers.Softmax()(mar)
    model = tf.keras.models.Model(inputs=[tokens,y],outputs=[output])
    return model

# %%
def prepare_data():
    N_classes = test["label_group"].nunique()
    #bert_layer = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1",\
                               #trainable=True)
    #vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
    #do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()
    #tokenizer = tokenization.FullTokenizer(vocab_file,do_lower_case)
    xtr,xts,ytr,yts = train_test_split(test["cleaned_title"].values,test["encoded_label_group"].values,\
                                      test_size =0.33,stratify=test["encoded_label_group"].values,\
                                      random_state=42)
    mx_len = 0
    for tx in test["title"].values :
        seq = tx.split()
        if len(seq) > mx_len :
            mx_len = len(seq)
    Xtr = bert_encode(xtr,tokenizer,max_len=mx_len)
    Xts = bert_encode(xts,tokenizer,max_len=mx_len)
    return Xtr,Xts,ytr,yts,N_classes,mx_len

# %%
Xtr,Xts,ytr,yts,N_classes,max_len = prepare_data()

# %%
print(f"The max sequence length to use equal : {max_len}")
# Out:
# The max sequence length to use equal : 61

# %%
print(f"The number of distinct class ={N_classes}")
# Out:
# The number of distinct class =11014

# %%
train_data = (Xtr[0],ytr)
val_data = (Xts[0],yts)

# %%
model = build_model(model,N_classes,max_len=max_len)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),loss=tf.keras.losses.sparse_categorical_crossentropy,\
             metrics="accuracy")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 61)]         0
# __________________________________________________________________________________________________
# bert (TFBertMainLayer)          TFBaseModelOutputWit 110617344   input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 768)          3072        bert[0][1]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None,)]            0
# __________________________________________________________________________________________________
# head/arc_margin (ArcMarginProdu (None, 11014)        8458752     batch_normalization[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# softmax (Softmax)               (None, 11014)        0           head/arc_margin[0][0]
# ==================================================================================================
# Total params: 119,079,168
# Trainable params: 119,077,632
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
model.fit(train_data,ytr,validation_data=(val_data,yts),epochs=30,batch_size = 16)
# Out:
# Epoch 1/30
# 1435/1435 [==============================] - 272s 179ms/step - loss: 24.0030 - accuracy: 0.0000e+00 - val_loss: 23.4355 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 22.9978 - accuracy: 0.0000e+00 - val_loss: 22.1282 - val_accuracy: 0.0017
# Epoch 3/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 21.5139 - accuracy: 0.0019 - val_loss: 20.9834 - val_accuracy: 0.0128
# Epoch 4/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 20.1635 - accuracy: 0.0112 - val_loss: 20.0275 - val_accuracy: 0.0217
# Epoch 5/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 19.0029 - accuracy: 0.0190 - val_loss: 19.2510 - val_accuracy: 0.0311
# Epoch 6/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 17.9943 - accuracy: 0.0260 - val_loss: 18.5768 - val_accuracy: 0.0420
# Epoch 7/30
# 1435/1435 [==============================] - 256s 178ms/step - loss: 17.0332 - accuracy: 0.0374 - val_loss: 17.9681 - val_accuracy: 0.0516
# Epoch 8/30
# 1435/1435 [==============================] - 256s 179ms/step - loss: 16.1501 - accuracy: 0.0446 - val_loss: 17.4446 - val_accuracy: 0.0612
# Epoch 9/30
# 1435/1435 [==============================] - 257s 179ms/step - loss: 15.3138 - accuracy: 0.0595 - val_loss: 16.9643 - val_accuracy: 0.0708
# Epoch 10/30
# 1435/1435 [==============================] - 258s 180ms/step - loss: 14.5936 - accuracy: 0.0668 - val_loss: 16.5288 - val_accuracy: 0.0817
# Epoch 11/30
# 1435/1435 [==============================] - 257s 179ms/step - loss: 13.8599 - accuracy: 0.0782 - val_loss: 16.1237 - val_accuracy: 0.0899
# Epoch 12/30
# 1435/1435 [==============================] - 258s 180ms/step - loss: 13.1447 - accuracy: 0.0964 - val_loss: 15.7520 - val_accuracy: 0.1002
# Epoch 13/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 12.5705 - accuracy: 0.1049 - val_loss: 15.3871 - val_accuracy: 0.1132
# Epoch 14/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 11.8955 - accuracy: 0.1249 - val_loss: 15.0960 - val_accuracy: 0.1217
# Epoch 15/30
# 1435/1435 [==============================] - 253s 177ms/step - loss: 11.3194 - accuracy: 0.1380 - val_loss: 14.7805 - val_accuracy: 0.1362
# Epoch 16/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 10.8082 - accuracy: 0.1564 - val_loss: 14.5020 - val_accuracy: 0.1439
# Epoch 17/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 10.1938 - accuracy: 0.1794 - val_loss: 14.2365 - val_accuracy: 0.1509
# Epoch 18/30
# 1435/1435 [==============================] - 256s 178ms/step - loss: 9.7084 - accuracy: 0.1931 - val_loss: 13.9884 - val_accuracy: 0.1600
# Epoch 19/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 9.2581 - accuracy: 0.2083 - val_loss: 13.7678 - val_accuracy: 0.1708
# Epoch 20/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 8.7197 - accuracy: 0.2294 - val_loss: 13.5573 - val_accuracy: 0.1790
# Epoch 21/30
# 1435/1435 [==============================] - 255s 177ms/step - loss: 8.2421 - accuracy: 0.2470 - val_loss: 13.3447 - val_accuracy: 0.1880
# Epoch 22/30
# 1435/1435 [==============================] - 256s 178ms/step - loss: 7.7790 - accuracy: 0.2737 - val_loss: 13.1509 - val_accuracy: 0.1989
# Epoch 23/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 7.5034 - accuracy: 0.2816 - val_loss: 12.9666 - val_accuracy: 0.2056
# Epoch 24/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 7.0240 - accuracy: 0.3127 - val_loss: 12.7860 - val_accuracy: 0.2119
# Epoch 25/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 6.6863 - accuracy: 0.3326 - val_loss: 12.6409 - val_accuracy: 0.2184
# Epoch 26/30
# 1435/1435 [==============================] - 254s 177ms/step - loss: 6.2314 - accuracy: 0.3620 - val_loss: 12.4882 - val_accuracy: 0.2245
# Epoch 27/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 5.9281 - accuracy: 0.3860 - val_loss: 12.3230 - val_accuracy: 0.2320
# Epoch 28/30
# 1435/1435 [==============================] - 252s 176ms/step - loss: 5.5644 - accuracy: 0.4094 - val_loss: 12.1909 - val_accuracy: 0.2359
# Epoch 29/30
# 1435/1435 [==============================] - 255s 177ms/step - loss: 5.2099 - accuracy: 0.4446 - val_loss: 12.0531 - val_accuracy: 0.2428
# Epoch 30/30
# 1435/1435 [==============================] - 255s 178ms/step - loss: 4.9294 - accuracy: 0.4619 - val_loss: 11.9405 - val_accuracy: 0.2460

# %%
model.save("model")

# %%
def get_layer_index(model, layer_name, not_found=None):
    """get model's layer index by layer's name"""
    for i, layer in enumerate(model.layers):
        if layer.name == layer_name:
            return i
    return not_found

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 61)]         0
# __________________________________________________________________________________________________
# bert (TFBertMainLayer)          TFBaseModelOutputWit 110617344   input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 768)          3072        bert[0][1]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None,)]            0
# __________________________________________________________________________________________________
# head/arc_margin (ArcMarginProdu (None, 11014)        8458752     batch_normalization[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# softmax (Softmax)               (None, 11014)        0           head/arc_margin[0][0]
# ==================================================================================================
# Total params: 119,079,168
# Trainable params: 119,077,632
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
md = tf.keras.models.Model(inputs=model.layers[1].input,outputs=model.layers[1].output)

# %%
md.save("bert_embedding")
